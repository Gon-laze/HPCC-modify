# %%
import random
import string

# %%
#tmpTest
# 生成对应流的flow.txt
flowf = open("flow.txt", "w", encoding="utf-8")


# MICE_num = 135

# GAME_num = 30
big_flow_num = 135
big_flow_num = 135

topoNode = 5
switchNode = 1

# flowNum = small_flow_num+mid_flow_num+big_flow_num
flowNum = 300

flowf.write(str(flowNum)+"\n")

dir_allList = [
    ["MICE"],
    ["GAME", "VMEETING", "VOICE"],
    ["VOD", "FILE"]
]

i = 0
for classIndex in range(0, 3):
    for dir in dir_allList[classIndex]:
#         j = 0
        print(dir)
        file_list = [f for f in os.listdir(dir) if os.path.isfile(dir+"/"+f) and f[-4:]==".txt"]
        print(file_list)
        for txtName in file_list:
            file = open(dir+"/"+txtName, "r", encoding="utf-8")
            line = file.readline().split("\n")
            print(line)
            flowf.write(str(i%(topoNode-1-switchNode)+1)+" 4 3 100 "+line[0]+" 2\n")
            i += 1
            file.close()
    


# # 0: src; others: des
# for i in range(0, flowNum):
# #     if (i<20):
# #         f = open("../CPinfo_"+str(i)+".txt", "r", encoding="utf-8")
# #     elif (i<40):
# #         f = open("../big-small-txt3/64KB_"+str(i-20)+".txt", "r", encoding="utf-8")
# #     else:
# #         f = open("../big-small-txt3/1MB_"+str(i-40)+".txt", "r", encoding="utf-8")
#     if (i<small_flow_num):    
#         f = open("high/high_"+str(i)+".txt", "r", encoding="utf-8")
#     elif (i<(small_flow_num+mid_flow_num)):
#         f = open("middle/middle_"+str(i-small_flow_num)+".txt", "r", encoding="utf-8")
#     else:
#         f = open("low/low_"+str(i-(small_flow_num+mid_flow_num))+".txt", "r", encoding="utf-8")
#     line = f.readline().split('\n')
#     # 还没试验过换端口和优先级，可以后续试试
#     flowf.write(str(i%(topoNode-1-switchNode)+1)+" 4 3 100 "+line[0]+" 2\n")
#     f.close()
# flowf.close()
# Out:
# MICE
# ['MICE_107.txt', 'MICE_66.txt', 'MICE_112.txt', 'MICE_113.txt', 'MICE_33.txt', 'MICE_111.txt', 'MICE_50.txt', 'MICE_65.txt', 'MICE_134.txt', 'MICE_68.txt', 'MICE_5.txt', 'MICE_80.txt', 'MICE_130.txt', 'MICE_125.txt', 'MICE_31.txt', 'MICE_29.txt', 'MICE_7.txt', 'MICE_119.txt', 'MICE_104.txt', 'MICE_128.txt', 'MICE_4.txt', 'MICE_101.txt', 'MICE_21.txt', 'MICE_19.txt', 'MICE_49.txt', 'MICE_122.txt', 'MICE_28.txt', 'MICE_120.txt', 'MICE_0.txt', 'MICE_64.txt', 'MICE_89.txt', 'MICE_95.txt', 'MICE_17.txt', 'MICE_90.txt', 'MICE_70.txt', 'MICE_78.txt', 'MICE_18.txt', 'MICE_25.txt', 'MICE_133.txt', 'MICE_30.txt', 'MICE_123.txt', 'MICE_51.txt', 'MICE_58.txt', 'MICE_55.txt', 'MICE_91.txt', 'MICE_56.txt', 'MICE_87.txt', 'MICE_6.txt', 'MICE_23.txt', 'MICE_36.txt', 'MICE_96.txt', 'MICE_108.txt', 'MICE_14.txt', 'MICE_98.txt', 'MICE_114.txt', 'MICE_1.txt', 'MICE_75.txt', 'MICE_116.txt', 'MICE_72.txt', 'MICE_76.txt', 'MICE_10.txt', 'MICE_63.txt', 'MICE_34.txt', 'MICE_121.txt', 'MICE_86.txt', 'MICE_103.txt', 'MICE_83.txt', 'MICE_102.txt', 'MICE_61.txt', 'MICE_38.txt', 'MICE_71.txt', 'MICE_48.txt', 'MICE_60.txt', 'MICE_124.txt', 'MICE_46.txt', 'MICE_82.txt', 'MICE_109.txt', 'MICE_54.txt', 'MICE_100.txt', 'MICE_37.txt', 'MICE_42.txt', 'MICE_99.txt', 'MICE_127.txt', 'MICE_110.txt', 'MICE_115.txt', 'MICE_41.txt', 'MICE_2.txt', 'MICE_32.txt', 'MICE_43.txt', 'MICE_85.txt', 'MICE_59.txt', 'MICE_47.txt', 'MICE_13.txt', 'MICE_24.txt', 'MICE_126.txt', 'MICE_16.txt', 'MICE_44.txt', 'MICE_93.txt', 'MICE_69.txt', 'MICE_73.txt', 'MICE_129.txt', 'MICE_27.txt', 'MICE_94.txt', 'MICE_97.txt', 'MICE_74.txt', 'MICE_77.txt', 'MICE_8.txt', 'MICE_88.txt', 'MICE_11.txt', 'MICE_35.txt', 'MICE_118.txt', 'MICE_20.txt', 'MICE_3.txt', 'MICE_62.txt', 'MICE_53.txt', 'MICE_39.txt', 'MICE_106.txt', 'MICE_67.txt', 'MICE_79.txt', 'MICE_9.txt', 'MICE_92.txt', 'MICE_52.txt', 'MICE_45.txt', 'MICE_131.txt', 'MICE_12.txt', 'MICE_22.txt', 'MICE_105.txt', 'MICE_84.txt', 'MICE_132.txt', 'MICE_57.txt', 'MICE_117.txt', 'MICE_26.txt', 'MICE_40.txt', 'MICE_81.txt', 'MICE_15.txt']
# ['4102', '']
# ['5862', '']
# ['2297', '']
# ['2288', '']
# ['3534', '']
# ['2148', '']
# ['2293', '']
# ['2161', '']
# ['4574', '']
# ['2302', '']
# ['3238', '']
# ['2228', '']
# ['3229', '']
# ['2221', '']
# ['2360', '']
# ['2151', '']
# ['2408', '']
# ['4851', '']
# ['4929', '']
# ['2367', '']
# ['2823', '']
# ['3698', '']
# ['2874', '']
# ['2228', '']
# ['3600', '']
# ['2289', '']
# ['2293', '']
# ['2287', '']
# ['2149', '']
# ['3096', '']
# ['4400', '']
# ['2307', '']
# ['2243', '']
# ['3901', '']
# ['6327', '']
# ['2299', '']
# ['2154', '']
# ['6239', '']
# ['3224', '']
# ['2215', '']
# ['5580', '']
# ['2286', '']
# ['2371', '']
# ['2150', '']
# ['2160', '']
# ['2293', '']
# ['5083', '']
# ['2555', '']
# ['2557', '']
# ['7688', '']
# ['2291', '']
# ['5165', '']
# ['7240', '']
# ['2175', '']
# ['3952', '']
# ['2290', '']
# ['2223', '']
# ['1674', '']
# ['4231', '']
# ['6388', '']
# ['4966', '']
# ['2228', '']
# ['2300', '']
# ['3092', '']
# ['3769', '']
# ['4756', '']
# ['3216', '']
# ['4218', '']
# ['2288', '']
# ['2371', '']
# ['8155', '']
# ['2293', '']
# ['2281', '']
# ['3290', '']
# ['2290', '']
# ['2823', '']
# ['2293', '']
# ['2153', '']
# ['2786', '']
# ['3362', '']
# ['6821', '']
# ['3355', '']
# ['2153', '']
# ['2291', '']
# ['2484', '']
# ['2152', '']
# ['2163', '']
# ['3628', '']
# ['4303', '']
# ['5106', '']
# ['2160', '']
# ['2552', '']
# ['2511', '']
# ['8068', '']
# ['2369', '']
# ['2377', '']
# ['6808', '']
# ['2547', '']
# ['2150', '']
# ['4725', '']
# ['2227', '']
# ['4653', '']
# ['2293', '']
# ['2551', '']
# ['6036', '']
# ['5220', '']
# ['2555', '']
# ['2221', '']
# ['2805', '']
# ['2227', '']
# ['2366', '']
# ['2414', '']
# ['7993', '']
# ['2283', '']
# ['3607', '']
# ['2150', '']
# ['2226', '']
# ['7132', '']
# ['2214', '']
# ['7982', '']
# ['3680', '']
# ['4217', '']
# ['2293', '']
# ['2293', '']
# ['3768', '']
# ['8067', '']
# ['2290', '']
# ['2290', '']
# ['2367', '']
# ['2153', '']
# ['2685', '']
# ['2362', '']
# ['2554', '']
# ['2224', '']
# ['2300', '']
# GAME
# ['GAME_3.txt', 'GAME_8.txt', 'GAME_4.txt', 'GAME_9.txt', 'GAME_7.txt', 'GAME_1.txt', 'GAME_5.txt', 'GAME_2.txt', 'GAME_0.txt', 'GAME_6.txt']
# ['298243', '']
# ['910508', '']
# ['796274', '']
# ['338595', '']
# ['297527', '']
# ['302860', '']
# ['264822', '']
# ['726717', '']
# ['352567', '']
# ['315980', '']
# VMEETING
# ['VMEETING_4.txt', 'VMEETING_6.txt', 'VMEETING_1.txt', 'VMEETING_2.txt', 'VMEETING_0.txt', 'VMEETING_8.txt', 'VMEETING_3.txt', 'VMEETING_7.txt', 'VMEETING_9.txt', 'VMEETING_5.txt']
# ['2250895', '']
# ['47544', '']
# ['934044', '']
# ['535563', '']
# ['467529', '']
# ['22142943', '']
# ['11212852', '']
# ['10241484', '']
# ['6791332', '']
# ['402194', '']
# VOICE
# ['VOICE_3.txt', 'VOICE_2.txt', 'VOICE_0.txt', 'VOICE_5.txt', 'VOICE_7.txt', 'VOICE_4.txt', 'VOICE_9.txt', 'VOICE_1.txt', 'VOICE_6.txt', 'VOICE_8.txt']
# ['1761892', '']
# ['866873', '']
# ['33752', '']
# ['3929899', '']
# ['10000', '']
# ['104364', '']
'FILE_77.txt', 'FILE_53.txt', 'FILE_61.txt', 'FILE_79.txt', 'FILE_57.txt', 'FILE_89.txt', 'FILE_36.txt', 'FILE_75.txt', 'FILE_1.txt', 'FILE_81.txt', 'FILE_45.txt', 'FILE_29.txt', 'FILE_11.txt', 'FILE_67.txt', 'FILE_22.txt', 'FILE_68.txt', 'FILE_74.txt', 'FILE_52.txt', 'FILE_31.txt', 'FILE_86.txt', 'FILE_49.txt', 'FILE_14.txt', 'FILE_66.txt', 'FILE_5.txt', 'FILE_78.txt', 'FILE_48.txt', 'FILE_56.txt', 'FILE_0.txt', 'FILE_70.txt', 'FILE_20.txt', 'FILE_2.txt', 'FILE_10.txt', 'FILE_9.txt', 'FILE_47.txt', 'FILE_24.txt', 'FILE_21.txt', 'FILE_35.txt', 'FILE_51.txt', 'FILE_6.txt', 'FILE_16.txt', 'FILE_39.txt', 'FILE_28.txt', 'FILE_27.txt', 'FILE_3.txt', 'FILE_41.txt', 'FILE_8.txt', 'FILE_76.txt', 'FILE_26.txt', 'FILE_12.txt', 'FILE_7.txt']
# ['19305', '']
# ['2376876', '']
# ['14808320', '']
# ['15210', '']
# ['57720', '']
# ['810498', '']
# ['12022846', '']
# ['3594153', '']
# ['269146', '']
# ['23471', '']
# ['1249560', '']
# ['329424', '']
# ['17554', '']
# ['2269192', '']
# ['6244772', '']
# ['5636747', '']
# ['19305', '']
# ['28900', '']
# ['7714714', '']
# ['14014', '']
# ['2550923', '']
# ['75660', '']
# ['8147494', '']
# ['6629164', '']
# ['1001111', '']
# ['43213', '']
# ['832551', '']
# ['8974479', '']
# ['43169564', '']
# ['12771213', '']
# ['276639', '']
# ['9213437', '']
# ['39592', '']
# ['8080544', '']
# ['7956574', '']
# ['8163612', '']
# ['95532', '']
# ['9906285', '']
# ['2147179', '']
# ['21211', '']
# ['515502', '']
# ['14508', '']
# ['8381714', '']
# ['19563', '']
# ['7628803', '']
# ['13426875', '']
# ['8941637', '']
# ['6222453', '']
# ['249286', '']
# ['2041051', '']
# ['8631', '']
# ['3457697', '']
# ['7556197', '']
# ['11882600', '']
# ['97513846', '']
# ['8963993', '']
# ['2229754', '']
# ['6895519', '']
# ['6413553', '']
# ['2542913', '']
# ['2853423', '']
# ['1948313', '']
# ['167921', '']
# ['1584403', '']
# ['15111218', '']
# ['49165', '']
# ['9278', '']
# ['20444', '']
# ['2323282', '']
# ['13013569', '']
# ['3356254', '']
# ['266395219', '']
# ['13603225', '']
# ['43616021', '']
# ['8214948', '']
# ['15400202', '']
# ['83636', '']
# ['8794960', '']
# ['2611316', '']
# ['17820', '']
# ['2096158', '']
# ['98864087', '']
# ['3367597', '']
# ['14439205', '']
# ['2397579', '']
# ['266405262', '']
# ['3335902', '']
# ['43169845', '']
# ['2146821', '']
# ['98875818', '']
