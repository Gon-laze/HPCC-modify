# %%
import os

# %%
dir_list = [dir for dir in os.listdir("./") if os.path.isdir(dir) and dir != ".ipynb_checkpoints"]
dir_list
# Out:
# ['middle', 'low', 'high']

# %%
for dir in dir_list:
    count = 0;
    file_list = [f for f in os.listdir(dir) if os.path.isfile(dir+"/"+f) and f[-4:]==".txt"]
    print(file_list)
    for f in file_list:
        os.rename(dir+"/"+f, dir+"/"+dir+"_"+str(count)+".txt")
        count += 1
# Out:
# ['王者荣耀_2_123.151.68.170-192.168.2.3-17-18047-60111.txt', 'voipbuster2b_131.202.240.86-131.202.240.87-63953-10111-17.txt', '微信视频_12_49.123.116.149-27.155.122.38-17-62789-8000.txt', '王者荣耀_11_192.168.2.5-157.148.39.44-17-53016-16224.txt', '腾讯会议_7_175.6.90.22-49.123.116.149-17-8000-61009.txt', '和平精英_1_192.168.2.2-114.222.113.34-17-50895-57134.txt', '腾讯会议_14_175.6.90.22-49.123.116.149-17-8000-61009.txt', 'facebook_audio4_131.202.240.185-131.202.243.255-35072-35072-17.txt', 'facebook_audio4_131.202.243.98-224.0.0.251-59668-59668-17.txt', '和平精英_15_192.168.2.6-112.80.145.151-17-59376-40603.txt', 'skype_audio3_131.202.242.81-131.202.243.255-35072-35072-17.txt', 'facebook_audio3_10.0.2.15-173.252.79.87-52942-25027-17.txt', '微信视频电话_4_119.167.201.38-192.168.0.105-17-8080-58618.txt', '微信视频_13_49.123.116.149-27.155.122.38-17-62789-8000.txt', 'voipbuster_4b_131.202.240.87-131.202.240.242-14403-30453-17.txt', '和平精英_9_112.80.145.151-192.168.2.6-17-40603-59376.txt', '王者荣耀_10_157.148.39.44-192.168.2.5-
# ...
